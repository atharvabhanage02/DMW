# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('t20.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                  Player       Span  Mat Inns  NO  Runs   HS  \
# 0           0         V Kohli (INDIA)  2010-2019   75   70  20  2633  94*
# 1           1       RG Sharma (INDIA)  2007-2019  104   96  14  2633  118
# 2           2         MJ Guptill (NZ)  2009-2019   83   80   7  2436  105
# 3           3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75
# 4           4        BB McCullum (NZ)  2005-2015   71   70  10  2140  123
#
#      Ave    BF      SR 100  50  0   4s   6s  Unnamed: 15
# 0  52.66  1907  138.07   0  24  2  247   71          NaN
# 1   32.1  1905  138.21   4  19  6  234  120          NaN
# 2  33.36  1810  134.58   2  15  2  215  113          NaN
# 3  30.58  1824  124.06   0   7  1  186   61          NaN
# 4  35.66  1571  136.21   2  13  3  199   91          NaN

# %%
sns.countplot(data=df,x=df['Inns'].head(10))
# Out:
# <AxesSubplot:xlabel='Inns', ylabel='count'>

# %%
df1 = pd.read_csv('Pizza Sales.csv')

# %%
df1.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ...

# %%
sns.countplot(data=df1,x='pizza_size')
# Out:
# <AxesSubplot:xlabel='pizza_size', ylabel='count'>

# %%
sns.countplot(data=df1,x='pizza_size',hue='pizza_category')
# Out:
# <AxesSubplot:xlabel='pizza_size', ylabel='count'>

# %%
ax = df1.plot(figsize=(18,12),title='Pizza Sales')

# %%
df1['total_price'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1['total_price'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.scatter(x='Inns',y='Runs')
# Out:
# <AxesSubplot:xlabel='Inns', ylabel='Runs'>

# %%
df1.hist(column='quantity')
# Out:
# array([[<AxesSubplot:title={'center':'quantity'}>]], dtype=object)

# %%
plt.pie(df['Runs'].head(5),labels=df['Player'].head(5),autopct='%0.1f%%',explode = (0.1,0,0,0,0))
plt.show()

# %%
df.head(5)
# Out:
#    Unnamed: 0                  Player       Span  Mat Inns  NO  Runs   HS  \
# 0           0         V Kohli (INDIA)  2010-2019   75   70  20  2633  94*
# 1           1       RG Sharma (INDIA)  2007-2019  104   96  14  2633  118
# 2           2         MJ Guptill (NZ)  2009-2019   83   80   7  2436  105
# 3           3  Shoaib Malik (ICC/PAK)  2006-2019  111  104  30  2263   75
# 4           4        BB McCullum (NZ)  2005-2015   71   70  10  2140  123
#
#      Ave    BF      SR 100  50  0   4s   6s  Unnamed: 15
# 0  52.66  1907  138.07   0  24  2  247   71          NaN
# 1   32.1  1905  138.21   4  19  6  234  120          NaN
# 2  33.36  1810  134.58   2  15  2  215  113          NaN
# 3  30.58  1824  124.06   0   7  1  186   61          NaN
# 4  35.66  1571  136.21   2  13  3  199   91          NaN

# %%
plt.stackplot(df['Mat'].head(5),df['SR'].head())
plt.xlabel('Matches Played')
plt.ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
data = list([df['Mat'].head(10),df['SR'].head(10),df['Runs'].head(10)])

# %%
data
# Out:
# [0     75
#  1    104
#  2     83
#  3    111
#  4     71
#  5     76
#  6     86
#  7     65
#  8     81
#  9     72
#  Name: Mat, dtype: int64,
#  0    138.07
#  1    138.21
#  2    134.58
#  3    124.06
#  4    136.21
#  5    140.85
#  6    135.72
#  7    134.81
#  8    126.24
#  9    137.68
#  Name: SR, dtype: object,
#  0    2633
#  1    2633
#  2    2436
#  3    2263
#  4    2140
#  5    2079
#  6    2002
#  7    1936
#  8    1934
#  9    1929
#  Name: Runs, dtype: object]

# %%
plt.scatter(df['Mat'].head(10),df['Runs'].head(10))
plt.scatter(df['Mat'].head(10),df['SR'].head(10))
plt.legend(['Mat','Runs'])
plt.title('Matches Vs Runs and SR')
plt.xlabel('Matches')
plt.ylabel('Runs SR')
plt.show()
